# %% [raw]
# ---
# title: Testing some notebook integration
# ---

# %%
import bamboost

coll = bamboost.Collection.fromUID["A529F9DDB8 - projects/25-rough-surface/data"]
coll.df
# Out:
#          name                 created_at description  \
# 0  3b228f0689 2025-03-27 16:25:16.730489
# 1  7408479385 2025-03-25 11:23:29.402630
# 2  946a651d11 2025-03-28 09:00:22.244929
# 3  d26431b536 2025-03-28 09:04:41.539729
# 4  d4893620e0 2025-03-28 08:54:19.710545
# 5  f96534a0b5 2025-03-27 17:01:17.104536
# 6  fcf65de5d1 2025-03-27 15:25:03.830086
# 7        test 2025-03-27 12:21:58.284097
#
#                                               status  submitted     E    T  \
# 0                                           finished       True  40.0  1.0
# 1                                        initialized      False   NaN  NaN
# 2  failed [\n\n*** ------------------------------...       True  40.0  1.0
# 3  failed [\n\n*** ------------------------------...       True  40.0  1.0
# 4  failed [\n\n*** ------------------------------...       True  40.0  1.0
# 5                                            started      False  40.0  1.0
# 6                                           finished       True  40.0  1.0
# 7                                           finished       True  40.0  1.0
#
#                                         bottom_curve   dt   eps  ...   nu  \
# 0  {'amp': 0.1, 'end': 2.6, 'frequency': 1, 'star...  1.0  0.05  ...  0.3
# 1                                                NaN  NaN   NaN  ...  NaN
# 2  {'amp': 0.25, 'end': 2.6, 'frequency': 1, 'sta...  1.0  0.05  ...  0.3
# 3  {'amp': 0.125, 'end': 2.6, 'frequency': 1, 'st...  1.0  0.05  ...  0.3
# 4  {'amp': 0.25, 'end': 2.6, 'frequency': 1, 'sta...  1.0  0.05  ...  0.3
# 5  {'amp': 0.1, 'end': 2.6, 'frequency': 1, 'star...  1.0  0.05  ...  0.3
# 6  {'amp': 0.1, 'end': 2.6, 'frequency': 1, 'star...  1.0  0.05  ...  0.3
# 7  {'amp': 0.05, 'end': 2.6666666666666665, 'freq...  1.0  0.05  ...  0.3
#
#   quadrature_degree  residual_factor  rho  rho_inf      rigid_v  \
# 0               4.0            0.001  0.2     0.98   [1.0, 0.0]
# 1               NaN              NaN  NaN      NaN          NaN
# 2               4.0            0.001  0.2     0.98  [1.75, 0.0]
# 3               4.0            0.001  0.2     0.98  [1.75, 0.0]
# 4               4.0            0.001  0.2     0.98  [1.75, 0.0]
# 5               4.0            0.001  0.2     0.98  [1.75, 0.0]
# 6               4.0            0.001  0.2     0.98   [1.0, 0.0]
# 7               4.0            0.001  0.2     0.98   [1.0, 0.0]
#
#    time_step_factor                                          top_curve  \
# 0               5.0  {'amp': 0.1, 'end': 3.2, 'frequency': 2, 'star...
# 1               NaN                                                NaN
# 2              10.0  {'amp': 0.5, 'end': 3.2, 'frequency': 2, 'star...
# 3              10.0  {'amp': 0.5, 'end': 3.2, 'frequency': 2, 'star...
# 4              10.0  {'amp': 0.5, 'end': 3.2, 'frequency': 2, 'star...
# 5               5.0  {'amp': 0.1, 'end': 3.2, 'frequency': 2, 'star...
# 6               5.0  {'amp': 0.1, 'end': 3.2, 'frequency': 2, 'star...
# 7               5.0  {'amp': 0.05, 'end': 3.0, 'frequency': 3, 'sta...
#
#     used_dt  write_every
# 0  0.004775          5.0
# 1       NaN          NaN
# 2  0.009550          5.0
# 3  0.009550          5.0
# 4  0.009550          5.0
# 5  0.004775          5.0
# 6  0.004775          5.0
# 7  0.004775          5.0
#
# [8 rows x 25 columns]

# %% [markdown]
# Then, you can easily plot this

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(np.sin(np.linspace(0, 2 * np.pi, 100)));

# %% [markdown]
# ## Some more information
#
# $$a + b = \int x dt$$
#
# > [!info]
# > Callout
# >
# > What am I supposed to do with this?

# %%
# Some dummy python code with title
a = 2
a**4
# Out:
# 16
